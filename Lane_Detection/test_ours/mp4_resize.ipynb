# %%
import cv2

Vid=cv2.VideoCapture('차선영상.mp4')

if Vid.isOpened():
    fps=Vid.get(cv2.CAP_PROP_FPS)
    f_count=Vid.get(cv2.CAP_PROP_FPS)
    f_width=Vid.get(cv2.CAP_PROP_FPS)
    f_height=Vid.get(cv2.CAP_PROP_FPS)
    print('width,hegight',f_width,f_height)
    
    codec="DIVX"
    fourcc=cv2.VideoWriter_fourcc(*codec)
    encoded_avi=cv2.VideoWriter("car_train.mp4")
while Vid.isOpened():
    ret,frame=Vid.read()
    if ret:
        re_frame=cv2.resize(frame,(1280,720))
        cv2.imshow('car_video',re_frame)
        key=cv2.waitKey(10)
        
        if key==ord('q'):
            break
    else:
        break
        
Vid.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# QObject::moveToThread: Current thread (0x563a5c995100) is not the object's thread (0x563a5bca3930).
# Cannot move to target thread (0x563a5c995100)
#
# ...
